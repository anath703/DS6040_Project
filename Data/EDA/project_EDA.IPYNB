# %% [markdown]
# # All-NBA Players EDA

# %% [markdown]
# ## Import Packages

# %%
import pandas as pd
import numpy as np
import os
from pandas_profiling import ProfileReport
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Preliminary Look at the Data

# %% [markdown]
# The first step will be to read in the data from our .csv file which has been compiled from Basketball Reference's [website](https://www.basketball-reference.com/).

# %%
df = pd.read_csv('full_data.csv')

# %% [markdown]
# The data looks to have been read in correctly and there is not any abnormalities below.

# %%
df
# Out:
#                      Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  \
# 0      Kareem Abdul-Jabbar*   C   41  LAL  74  1695  12.9  0.511  0.005
# 1                Mark Acres   C   26  BOS  62   632   8.2  0.507  0.009
# 2             Michael Adams  PG   26  DEN  77  2787  17.5  0.567  0.431
# 3               Mark Alarie  PF   25  WSB  74  1141  13.3  0.531  0.088
# 4               Randy Allen  SG   24  SAC   7    43   6.9  0.428  0.053
# ...                     ...  ..  ...  ...  ..   ...   ...    ...    ...
# 15438        Tremont Waters  PG   24  TOT   3    50   5.4  0.357  0.643
# 15439         Derrick White  SG   27  TOT  75  2199  14.8  0.549  0.461
# 15440       Justise Winslow  SF   25  TOT  48   774  13.1  0.479  0.257
# 15441          Moses Wright  PF   23  TOT   4    14  18.3  0.470  0.250
# 15442        Thaddeus Young  PF   33  TOT  52   845  17.0  0.548  0.176
#
#          FTr  ...  All_NBA_Pos  All_NBA_Team  All_NBA_Pts_Won  \
# 0      0.250  ...          NaN           NaN              NaN
# 1      0.421  ...          NaN           NaN              NaN
# 2      0.363  ...          NaN           NaN              NaN
# 3      0.202  ...          NaN           NaN              NaN
# 4      0.105  ...          NaN           NaN              NaN
# ...      ...  ...          ...           ...              ...
# 15438  0.000  ...          NaN           NaN              NaN
# 15439  0.294  ...          NaN           NaN              NaN
# 15440  0.257  ...          NaN           NaN              NaN
# 15441  0.750  ...          NaN           NaN              NaN
# 15442  0.180  ...          NaN           NaN              NaN
#
#        All_NBA_Pts_Max  All_NBA_Share  All_NBA_1st_Team_Votes  \
# 0                  NaN            NaN                     NaN
# 1                  NaN            NaN                     NaN
# 2                  NaN            NaN                     NaN
# 3                  NaN            NaN                     NaN
# 4                  NaN            NaN                     NaN
# ...                ...            ...                     ...
# 15438              NaN            NaN                     NaN
# 15439              NaN            NaN                     NaN
# 15440              NaN            NaN                     NaN
# 15441              NaN            NaN                     NaN
# 15442              NaN            NaN                     NaN
#
#        All_NBA_2nd_Team_Votes  All_NBA_3rd_Team_Votes       year  \
# 0                         NaN                     NaN  1988-1989
# 1                         NaN                     NaN  1988-1989
# 2                         NaN                     NaN  1988-1989
# 3                         NaN                     NaN  1988-1989
# 4                         NaN                     NaN  1988-1989
# ...                       ...                     ...        ...
# 15438                     NaN                     NaN  2021-2022
# 15439                     NaN                     NaN  2021-2022
# 15440                     NaN                     NaN  2021-2022
# 15441                     NaN                     NaN  2021-2022
# 15442                     NaN                     NaN  2021-2022
#
#        All_NBA_Boolean
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# ...                ...
# 15438            False
# 15439            False
# 15440            False
# 15441            False
# 15442            False
#
# [15443 rows x 37 columns]

# %% [markdown]
# Upon examining the data type of each column, it does not seem like there needs to be any changes.

# %%
df.dtypes
# Out:
# Player                     object
# Pos                        object
# Age                         int64
# Tm                         object
# G                           int64
# MP                          int64
# PER                       float64
# TS%                       float64
# 3PAr                      float64
# FTr                       float64
# ORB%                      float64
# DRB%                      float64
# TRB%                      float64
# AST%                      float64
# STL%                      float64
# BLK%                      float64
# TOV%                      float64
# USG%                      float64
# OWS                       float64
# DWS                       float64
# WS                        float64
# WS/48                     float64
# OBPM                      float64
# DBPM                      float64
# BPM                       float64
# VORP                      float64
# player_id                  object
# All_NBA_Pos                object
# All_NBA_Team               object
# All_NBA_Pts_Won           float64
# All_NBA_Pts_Max           float64
# All_NBA_Share             float64
# All_NBA_1st_Team_Votes    float64
# All_NBA_2nd_Team_Votes    float64
# All_NBA_3rd_Team_Votes    float64
# year                       object
# All_NBA_Boolean              bool
# dtype: object

# %% [markdown]
# Let's examine all the columns available and a value seen/associated with each column.

# %%
df.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr',
#        'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS',
#        'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP', 'player_id',
#        'All_NBA_Pos', 'All_NBA_Team', 'All_NBA_Pts_Won', 'All_NBA_Pts_Max',
#        'All_NBA_Share', 'All_NBA_1st_Team_Votes', 'All_NBA_2nd_Team_Votes',
#        'All_NBA_3rd_Team_Votes', 'year', 'All_NBA_Boolean'],
#       dtype='object')

# %% [markdown]
# There are 36 predictor variables available in the data set with our response variable being `All_NBA_Boolean` which will indicate if the player was elected to an All-NBA team that season.

# %%
len(df.columns)
# Out:
# 37

# %%
df.head(1).T
# Out:
#                                            0
# Player                  Kareem Abdul-Jabbar*
# Pos                                        C
# Age                                       41
# Tm                                       LAL
# G                                         74
# MP                                      1695
# PER                                     12.9
# TS%                                    0.511
# 3PAr                                   0.005
# FTr                                     0.25
# ORB%                                     7.3
# DRB%                                    14.2
# TRB%                                    11.0
# AST%                                     6.1
# STL%                                     1.1
# BLK%                                     2.9
# TOV%                                    11.5
# USG%                                    20.1
# OWS                                      0.9
# DWS                                      2.0
# WS                                       2.9
# WS/48                                  0.082
# OBPM                                    -1.9
# DBPM                                    -0.2
# BPM                                     -2.1
# VORP                                     0.0
# player_id                          abdulka01
# All_NBA_Pos                              NaN
# All_NBA_Team                             NaN
# All_NBA_Pts_Won                          NaN
# All_NBA_Pts_Max                          NaN
# All_NBA_Share                            NaN
# All_NBA_1st_Team_Votes                   NaN
# All_NBA_2nd_Team_Votes                   NaN
# All_NBA_3rd_Team_Votes                   NaN
# year                               1988-1989
# All_NBA_Boolean                        False

# %% [markdown]
# ## Correlation Matrix

# %% [markdown]
# The first place to start will be to examine the correlation between the predictor variables in our data set. This will be important because high correlation between predictors may be problematic for the models that are created.
#
# To examine the correlation, a list of columns need to be created. The predictors will be in the list as well as the response variable but variables that are known to have an impact on the response will be excluded. For example, the `All_NBA_Boolean` response variable will be directly correlated to `All_NBA_Pts_Won` or `All_NBA_1st_Team_Votes`. The only one of these "All_NBA_..." variables that will be included besides the response variable is `All_NBA_Share` (share of All-NBA votes) as it will be a fair quanatative measure the All-NBA prowess of a player.

# %%
cols_list = df.columns[0:28].to_list()
cols_list.extend(['All_NBA_Share', 'year', 'All_NBA_Boolean'])

# %%
df_abr = df[cols_list]

corr = df_abr.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_1f67d_row0_col0, #T_1f67d_row1_col1, #T_1f67d_row2_col2, #T_1f67d_row3_col3, #T_1f67d_row4_col4, #T_1f67d_row5_col5, #T_1f67d_row6_col6, #T_1f67d_row7_col7, #T_1f67d_row8_col8, #T_1f67d_row9_col9, #T_1f67d_row10_col10, #T_1f67d_row11_col11, #T_1f67d_row12_col12, #T_1f67d_row13_col13, #T_1f67d_row14_col14, #T_1f67d_row15_col15, #T_1f67d_row16_col16, #T_1f67d_row17_col17, #T_1f67d_row18_col18, #T_1f67d_row19_col19, #T_1f67d_row20_col20, #T_1f67d_row21_col21, #T_1f67d_row22_col22, #T_1f67d_row23_col23, #T_1f67d_row24_col24 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1f67d_row0_col1, #T_1f67d_row2_col0 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_1f67d_row0_col2, #T_1f67d_row0_col16, #T_1f67d_row1_col24, #T_1f67d_row5_col11, #T_1f67d_row6_col14, #T_1f67d_row15_col0, #T_1f67d_row18_col14 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_1f67d_row0_col3, #T_1f67d_row1_col6, #T_1f67d_row2_col12 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_1f67d_row0_col4, #T_1f67d_row2_col13, #T_1f67d_row5_col0, #T_1f67d_row5_col3, #T_1f67d_row5_col4, #T_1f67d_row5_col22, #T_1f67d_row11_col8 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_1f67d_row0_col5, #T_1f67d_row12_col18, #T_1f67d_row15_col9 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_1f67d_row0_col6, #T_1f67d_row0_col15, #T_1f67d_row4_col14, #T_1f67d_row6_col10, #T_1f67d_row6_col17, #T_1f67d_row8_col15 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_1f67d_row0_col7, #T_1f67d_row1_col7, #T_1f67d_row9_col16, #T_1f67d_row11_col18, #T_1f67d_row15_col20, #T_1f67d_row16_col6, #T_1f67d_row17_col5, #T_1f67d_row17_col12, #T_1f67d_row20_col5 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_1f67d_row0_col8, #T_1f67d_row1_col14, #T_1f67d_row3_col5, #T_1f67d_row3_col11, #T_1f67d_row16_col5, #T_1f67d_row19_col8, #T_1f67d_row20_col2 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_1f67d_row0_col9, #T_1f67d_row2_col9, #T_1f67d_row2_col20, #T_1f67d_row14_col9, #T_1f67d_row22_col7 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_1f67d_row0_col10, #T_1f67d_row2_col24, #T_1f67d_row5_col19, #T_1f67d_row12_col21, #T_1f67d_row19_col9, #T_1f67d_row24_col6 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_1f67d_row0_col11 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_1f67d_row0_col12, #T_1f67d_row8_col4, #T_1f67d_row8_col22, #T_1f67d_row8_col23, #T_1f67d_row11_col17, #T_1f67d_row12_col17, #T_1f67d_row14_col11, #T_1f67d_row18_col11, #T_1f67d_row23_col1 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_1f67d_row0_col13, #T_1f67d_row6_col21, #T_1f67d_row8_col19, #T_1f67d_row12_col16 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_1f67d_row0_col14 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_1f67d_row0_col17, #T_1f67d_row24_col13 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_1f67d_row0_col18, #T_1f67d_row21_col6, #T_1f67d_row21_col7, #T_1f67d_row21_col8, #T_1f67d_row23_col2, #T_1f67d_row24_col5 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_1f67d_row0_col19, #T_1f67d_row12_col13, #T_1f67d_row19_col6 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_1f67d_row0_col20, #T_1f67d_row6_col20, #T_1f67d_row6_col23, #T_1f67d_row8_col21, #T_1f67d_row10_col23, #T_1f67d_row11_col7, #T_1f67d_row20_col13 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_1f67d_row0_col21, #T_1f67d_row6_col4, #T_1f67d_row20_col1, #T_1f67d_row22_col11 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_1f67d_row0_col22, #T_1f67d_row5_col14, #T_1f67d_row6_col22, #T_1f67d_row8_col2, #T_1f67d_row9_col4, #T_1f67d_row9_col14 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_1f67d_row0_col23 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_1f67d_row0_col24, #T_1f67d_row7_col1, #T_1f67d_row11_col4, #T_1f67d_row12_col10 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_1f67d_row1_col0, #T_1f67d_row6_col16 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_1f67d_row1_col2, #T_1f67d_row2_col1 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_1f67d_row1_col3, #T_1f67d_row1_col18, #T_1f67d_row3_col16 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_1f67d_row1_col4, #T_1f67d_row6_col8, #T_1f67d_row20_col16 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_1f67d_row1_col5, #T_1f67d_row1_col9, #T_1f67d_row11_col13, #T_1f67d_row14_col24, #T_1f67d_row21_col11 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_1f67d_row1_col8, #T_1f67d_row8_col17, #T_1f67d_row23_col11, #T_1f67d_row24_col12, #T_1f67d_row24_col20 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_1f67d_row1_col10, #T_1f67d_row2_col14, #T_1f67d_row4_col6, #T_1f67d_row22_col20 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_1f67d_row1_col11, #T_1f67d_row9_col22, #T_1f67d_row20_col24 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_1f67d_row1_col12, #T_1f67d_row5_col21, #T_1f67d_row9_col19, #T_1f67d_row10_col1, #T_1f67d_row12_col19, #T_1f67d_row14_col6 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_1f67d_row1_col13, #T_1f67d_row12_col22 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_1f67d_row1_col15, #T_1f67d_row24_col17 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_1f67d_row1_col16, #T_1f67d_row3_col23, #T_1f67d_row21_col4 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_1f67d_row1_col17 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_1f67d_row1_col19, #T_1f67d_row11_col20, #T_1f67d_row16_col19 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_1f67d_row1_col20, #T_1f67d_row4_col12, #T_1f67d_row14_col5, #T_1f67d_row15_col5, #T_1f67d_row19_col7, #T_1f67d_row20_col6 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_1f67d_row1_col21 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_1f67d_row1_col22, #T_1f67d_row17_col4 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_1f67d_row1_col23, #T_1f67d_row12_col1 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_1f67d_row2_col3, #T_1f67d_row21_col17, #T_1f67d_row24_col15 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_1f67d_row2_col4, #T_1f67d_row5_col10, #T_1f67d_row14_col15, #T_1f67d_row24_col18, #T_1f67d_row24_col21 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_1f67d_row2_col5, #T_1f67d_row4_col8, #T_1f67d_row14_col7, #T_1f67d_row15_col7, #T_1f67d_row17_col6, #T_1f67d_row22_col8, #T_1f67d_row24_col8 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_1f67d_row2_col6, #T_1f67d_row9_col17, #T_1f67d_row9_col20, #T_1f67d_row11_col6, #T_1f67d_row11_col22, #T_1f67d_row15_col12 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_1f67d_row2_col7, #T_1f67d_row8_col13, #T_1f67d_row13_col8, #T_1f67d_row20_col15 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_1f67d_row2_col8, #T_1f67d_row6_col19, #T_1f67d_row9_col13, #T_1f67d_row13_col12, #T_1f67d_row21_col24 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_1f67d_row2_col10, #T_1f67d_row3_col14, #T_1f67d_row4_col17, #T_1f67d_row18_col16, #T_1f67d_row22_col14 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_1f67d_row2_col11, #T_1f67d_row7_col14, #T_1f67d_row11_col2 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_1f67d_row2_col15 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_1f67d_row2_col16, #T_1f67d_row4_col18 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_1f67d_row2_col17, #T_1f67d_row17_col2 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_1f67d_row2_col18, #T_1f67d_row20_col12 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_1f67d_row2_col19, #T_1f67d_row22_col21, #T_1f67d_row22_col24 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_1f67d_row2_col21, #T_1f67d_row16_col18, #T_1f67d_row19_col2 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_1f67d_row2_col22, #T_1f67d_row16_col15 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_1f67d_row2_col23, #T_1f67d_row9_col21 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_1f67d_row3_col0, #T_1f67d_row9_col1, #T_1f67d_row9_col2, #T_1f67d_row23_col0 {
#   background-color: #6180e9;
#   c

# %% [markdown]
# Examining which predictors are most correlated with each other (correlation > 0.50). We're not including `All_NBA_Share` and `All_NBA_Boolean` since intuitively we know they're highly correlated with one another and they each could represent the response variable.

# %%
corr_matrix = df_abr.corr().abs()

sol = (corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
                  .stack()
                  .sort_values(ascending=False))

sol_df = pd.DataFrame(sol).reset_index()
sol_df.rename(columns = {"level_0": "feature_1", "level_1": "feature_2", 0: "correlation"}, inplace = True)

sol_df.query("correlation >= 0.5 & feature_1 not in ('All_NBA_Boolean', 'All_NBA_Share') & feature_2 not in ('All_NBA_Boolean', 'All_NBA_Share')")
# Out:
#    feature_1 feature_2  correlation
# 0        OWS        WS     0.949795
# 1       OBPM       BPM     0.943777
# 2         WS      VORP     0.910833
# 3       DRB%      TRB%     0.896559
# 4        OWS      VORP     0.890711
# 5        PER      OBPM     0.888872
# 6        PER     WS/48     0.888699
# 7      WS/48       BPM     0.885443
# 8        PER       BPM     0.869902
# 9          G        MP     0.854114
# 10       DWS        WS     0.845497
# 11     WS/48      OBPM     0.844724
# 12        MP        WS     0.825086
# 13      ORB%      TRB%     0.823069
# 15        MP       DWS     0.796570
# 16       TS%     WS/48     0.758647
# 17       DWS      VORP     0.726618
# 18        MP       OWS     0.725893
# 19       PER       TS%     0.722998
# 23         G       DWS     0.676507
# 24      DBPM       BPM     0.675885
# 25       TS%       BPM     0.675835
# 26       TS%      OBPM     0.670429
# 28        MP      VORP     0.653035
# 29       OWS       DWS     0.636467
# 30         G        WS     0.634997
# 34       PER        WS     0.590870
# 35     WS/48      DBPM     0.579553
# 36       PER       OWS     0.579174
# 38       PER      VORP     0.562833
# 39       OWS      OBPM     0.562131
# 40        WS      OBPM     0.555123
# 41      OBPM      VORP     0.539867
# 42      3PAr      ORB%     0.536022
# 43        WS       BPM     0.532824
# 46       BPM      VORP     0.528112
# 47         G       OWS     0.521703
# 48        WS     WS/48     0.516072
# 49       OWS       BPM     0.502618
# 50        MP      OBPM     0.500346

# %% [markdown]
# There are many predictor variables with a considerably high correlation between them, which could prove to be problematic. This result is not necessarily surprising as our data set includes a plethora of basic and advanced statistics in the NBA and advanced statistics primarily manipulate the basic statistics. For example, advanced statistics like `PER` (*Player Efficiency Rating*) or `VORP` (*Value Over Replacement Player*) will inevitably draw from the same pool of basic statistics such as field goal percentage. Further, advanced statistics that aggregate statistics on both offense and defense like `WS` (*Win Share*) will be correlated with related predictors that focus only on offense or defense like `OWS` (*Offensive Win Share*).

# %% [markdown]
# ## EDA of All-NBA Players

# %% [markdown]
# The next phase of the EDA will to solely focus on the rows/players in the data set where the player was selected as an All-NBA selection so we can focus on what the measure of center is for the predictors in the data set.

# %%
df_all_NBA = round(df.query('All_NBA_Boolean'),2) # DF of just All-NBA players

df_all_NBA.median().reset_index()
# Out:
# C:\Users\caliz\AppData\Local\Temp\ipykernel_12408\1360446038.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_all_NBA.median().reset_index()
#                      index        0
# 0                      Age    27.00
# 1                        G    77.00
# 2                       MP  2797.00
# 3                      PER    23.30
# 4                      TS%     0.58
# 5                     3PAr     0.16
# 6                      FTr     0.39
# 7                     ORB%     4.85
# 8                     DRB%    17.95
# 9                     TRB%    11.50
# 10                    AST%    21.80
# 11                    STL%     1.90
# 12                    BLK%     1.40
# 13                    TOV%    12.45
# 14                    USG%    27.80
# 15                     OWS     7.10
# 16                     DWS     3.80
# 17                      WS    10.90
# 18                   WS/48     0.20
# 19                    OBPM     4.50
# 20                    DBPM     1.00
# 21                     BPM     5.20
# 22                    VORP     4.90
# 23         All_NBA_Pts_Won   303.50
# 24         All_NBA_Pts_Max   592.50
# 25           All_NBA_Share     0.54
# 26  All_NBA_1st_Team_Votes    15.00
# 27  All_NBA_2nd_Team_Votes    16.00
# 28  All_NBA_3rd_Team_Votes     4.50
# 29         All_NBA_Boolean     1.00

# %% [markdown]
# Some takeaways from the dataframe above are that the median value of `Age` indicates that All-NBA players are mostly veterans and not players who have recently entered the league. Further, the median value of `G` demonstrates that these players play a high majority of the 82-game NBA season and tends to contribute to the sentiment that "Availability is the best ability." The median for `PER` is also interesting knowing that a league-average `PER` is always 15.00, which means that these All-NBA players are above average from a `PER` perspective and makes logical sense.
#
# Let's see if there is a difference in the median values for these predictors in different eras of the NBA. This is not a perfect split to find distinct eras in the NBA but the split of the eras will be before and after the year 2000. Later in the project, this split of era will be adjusted and analyzed further.

# %%
df_all_NBA['Era'] = np.where(df_all_NBA['year'].str[0] == '1', 'Pre-2000', 'Post-2000')

# %%
def percentage_change(col1,col2):
    return ((col2 - col1) / col1) * 100

df_all_NBA_eras = df_all_NBA.groupby('Era').median().T
df_all_NBA_eras['% Change'] = percentage_change(df_all_NBA_eras['Pre-2000'], df_all_NBA_eras['Post-2000'])
df_all_NBA_eras = df_all_NBA_eras[df_all_NBA_eras.index.str.contains("All")==False]
df_all_NBA_eras.sort_values(by = '% Change', ascending = False)
# Out:
# Era    Post-2000  Pre-2000    % Change
# 3PAr        0.19      0.06  216.666667
# BLK%        1.60      1.20   33.333333
# AST%       23.85     18.95   25.857520
# DRB%       18.50     16.05   15.264798
# OBPM        4.70      4.30    9.302326
# USG%       28.95     26.50    9.245283
# WS/48       0.20      0.19    5.263158
# PER        23.70     22.60    4.867257
# TS%         0.58      0.57    1.754386
# TRB%       11.50     11.40    0.877193
# FTr         0.39      0.39    0.000000
# BPM         5.20      5.30   -1.886792
# WS         10.80     11.20   -3.571429
# Age        27.00     28.00   -3.571429
# TOV%       12.20     12.70   -3.937008
# VORP        4.80      5.00   -4.000000
# OWS         7.00      7.30   -4.109589
# G          76.00     80.00   -5.000000
# DWS         3.75      4.00   -6.250000
# MP       2703.00   2928.00   -7.684426
# DBPM        0.90      1.05  -14.285714
# STL%        1.70      2.00  -15.000000
# ORB%        4.30      6.35  -32.283465

# %% [markdown]
# The data frame above is very indicative to how basketball in the NBA may have changed before and after the year 2000. More specifically, it speaks to the characterstics of what the most elite NBA players have and how that has changed as basketball has evolved. First and foremost, there was over a 200% (!!!) increase in `3PAr` (*3-Point Attempt Rate*) in this new era of the NBA. Players who are dominant from the 3-point line like Stephen Curry have helped fuel this change and cause other elite NBA players to incorporate shooting from a distance in their repertoire. Another considerable change is in `USG%` (*Usage Percentage*) where it seems like All-NBA players in the post-2000 era have nearly 10% higher usage rate, which means these players are more involved when they are on the floor.
#
# On the other end of the spectrum, metrics that speak to how often a player plays like `G` (*Games*) or `MP` (*Minutes Played*) show that players may not need to play as often in a game or play as many games in a season to be of the All-NBA caliber.

# %% [markdown]
# # Median of Features Throughout the Seasons

# %% [markdown]
# Building off of the last part of the EDA, let's further examine how the measure of center for our predictors (excluding predictors that are related to the response i.e including 'All-NBA') have changed throughout the seasons.

# %%
cols_all_list = ['Age',  
                'PER', 
                'TS%', 
                '3PAr', 
                'FTr',
                'ORB%', 
                'DRB%', 
                'TRB%', 
                'AST%', 
                'STL%', 
                'BLK%', 
                'TOV%', 
                'USG%', 
                'OWS',
                'DWS', 
                'WS',
                'WS/48', 
                'OBPM', 
                'DBPM', 
                'BPM', 
                'VORP',
                'Pos']

# %% [markdown]
# Let's examine each of the predictors' median value for each season in the dataset and apply a gradient to demonstrate when the predictor was highest and when it was lowest. For example, `Age` was at its highest in the 1997-1998 season (31 years old) and amongst its lowest in the following 4-5 seasons after due to the light shading. A certain prominent older player in the mid-1990s must have been pushing the median of age up but then that player stopped playing at an elite level after 1997-1998.

# %%
cm = sns.light_palette("green", as_cmap=True)

df_group = df_all_NBA.groupby(['year'])[cols_all_list].median()
df_group.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_c5ab5_row0_col0, #T_c5ab5_row3_col17, #T_c5ab5_row10_col0, #T_c5ab5_row11_col0, #T_c5ab5_row13_col0, #T_c5ab5_row14_col0, #T_c5ab5_row16_col0, #T_c5ab5_row18_col0, #T_c5ab5_row18_col17, #T_c5ab5_row22_col0, #T_c5ab5_row23_col0, #T_c5ab5_row26_col0 {
#   background-color: #c4e0c4;
#   color: #000000;
# }
# #T_c5ab5_row0_col1, #T_c5ab5_row15_col1, #T_c5ab5_row21_col8 {
#   background-color: #b3d8b3;
#   color: #000000;
# }
# #T_c5ab5_row0_col2, #T_c5ab5_row1_col2, #T_c5ab5_row2_col2, #T_c5ab5_row31_col2, #T_c5ab5_row33_col2 {
#   background-color: #219021;
#   color: #f1f1f1;
# }
# #T_c5ab5_row0_col3, #T_c5ab5_row3_col3, #T_c5ab5_row11_col2, #T_c5ab5_row12_col2 {
#   background-color: #c9e3c9;
#   color: #000000;
# }
# #T_c5ab5_row0_col4, #T_c5ab5_row2_col4, #T_c5ab5_row5_col4, #T_c5ab5_row13_col18, #T_c5ab5_row15_col15, #T_c5ab5_row17_col10, #T_c5ab5_row20_col10, #T_c5ab5_row27_col10 {
#   background-color: #7dbd7d;
#   color: #000000;
# }
# #T_c5ab5_row0_col5, #T_c5ab5_row2_col1, #T_c5ab5_row9_col15, #T_c5ab5_row12_col12, #T_c5ab5_row16_col12, #T_c5ab5_row18_col15 {
#   background-color: #66b266;
#   color: #f1f1f1;
# }
# #T_c5ab5_row0_col6, #T_c5ab5_row29_col6 {
#   background-color: #74b974;
#   color: #f1f1f1;
# }
# #T_c5ab5_row0_col7, #T_c5ab5_row9_col14, #T_c5ab5_row15_col13 {
#   background-color: #7ebe7e;
#   color: #000000;
# }
# #T_c5ab5_row0_col8, #T_c5ab5_row3_col12, #T_c5ab5_row9_col1, #T_c5ab5_row9_col6, #T_c5ab5_row9_col7, #T_c5ab5_row10_col2, #T_c5ab5_row10_col3, #T_c5ab5_row10_col13, #T_c5ab5_row10_col15, #T_c5ab5_row11_col17, #T_c5ab5_row12_col0, #T_c5ab5_row12_col11, #T_c5ab5_row13_col2, #T_c5ab5_row14_col2, #T_c5ab5_row15_col0, #T_c5ab5_row15_col2, #T_c5ab5_row15_col4, #T_c5ab5_row15_col17, #T_c5ab5_row20_col17, #T_c5ab5_row21_col9, #T_c5ab5_row23_col14, #T_c5ab5_row23_col17, #T_c5ab5_row23_col18, #T_c5ab5_row23_col19, #T_c5ab5_row23_col20, #T_c5ab5_row25_col5, #T_c5ab5_row25_col10, #T_c5ab5_row25_col17, #T_c5ab5_row32_col4, #T_c5ab5_row32_col14, #T_c5ab5_row33_col16 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_c5ab5_row0_col9, #T_c5ab5_row1_col9, #T_c5ab5_row1_col18, #T_c5ab5_row2_col9, #T_c5ab5_row4_col0, #T_c5ab5_row4_col9, #T_c5ab5_row6_col0, #T_c5ab5_row10_col9, #T_c5ab5_row11_col9, #T_c5ab5_row13_col9, #T_c5ab5_row16_col18, #T_c5ab5_row17_col17, #T_c5ab5_row19_col18, #T_c5ab5_row22_col13, #T_c5ab5_row26_col10, #T_c5ab5_row26_col18, #T_c5ab5_row28_col4, #T_c5ab5_row28_col9, #T_c5ab5_row29_col9, #T_c5ab5_row31_col9, #T_c5ab5_row31_col17 {
#   background-color: #4ea64e;
#   color: #f1f1f1;
# }
# #T_c5ab5_row0_col10, #T_c5ab5_row1_col10, #T_c5ab5_row3_col4, #T_c5ab5_row17_col18 {
#   background-color: #cbe4cb;
#   color: #000000;
# }
# #T_c5ab5_row0_col11 {
#   background-color: #0f870f;
#   color: #f1f1f1;
# }
# #T_c5ab5_row0_col12, #T_c5ab5_row8_col17, #T_c5ab5_row11_col11, #T_c5ab5_row20_col11 {
#   background-color: #a6d2a6;
#   color: #000000;
# }
# #T_c5ab5_row0_col13, #T_c5ab5_row1_col11, #T_c5ab5_row7_col5, #T_c5ab5_row8_col13 {
#   background-color: #3d9e3d;
#   color: #f1f1f1;
# }
# #T_c5ab5_row0_col14 {
#   background-color: #90c790;
#   color: #000000;
# }
# #T_c5ab5_row0_col15, #T_c5ab5_row14_col15, #T_c5ab5_row25_col6, #T_c5ab5_row25_col8 {
#   background-color: #54a954;
#   color: #f1f1f1;
# }
# #T_c5ab5_row0_col16, #T_c5ab5_row2_col10, #T_c5ab5_row3_col10, #T_c5ab5_row4_col16, #T_c5ab5_row8_col10, #T_c5ab5_row10_col16, #T_c5ab5_row11_col16, #T_c5ab5_row14_col16, #T_c5ab5_row20_col18, #T_c5ab5_row21_col16, #T_c5ab5_row21_col18, #T_c5ab5_row23_col16, #T_c5ab5_row29_col4, #T_c5ab5_row33_col4 {
#   background-color: #bcdcbc;
#   color: #000000;
# }
# #T_c5ab5_row0_col17, #T_c5ab5_row6_col8, #T_c5ab5_row22_col17 {
#   background-color: #badbba;
#   color: #000000;
# }
# #T_c5ab5_row0_col18 {
#   background-color: #dbebdb;
#   color: #000000;
# }
# #T_c5ab5_row0_col19, #T_c5ab5_row15_col8, #T_c5ab5_row20_col19 {
#   background-color: #b8dab8;
#   color: #000000;
# }
# #T_c5ab5_row0_col20, #T_c5ab5_row9_col20, #T_c5ab5_row19_col20, #T_c5ab5_row33_col20 {
#   background-color: #67b267;
#   color: #f1f1f1;
# }
# #T_c5ab5_row1_col0, #T_c5ab5_row4_col10, #T_c5ab5_row5_col10, #T_c5ab5_row6_col18, #T_c5ab5_row7_col17, #T_c5ab5_row8_col4, #T_c5ab5_row9_col9, #T_c5ab5_row9_col18, #T_c5ab5_row11_col4, #T_c5ab5_row12_col4, #T_c5ab5_row14_col4, #T_c5ab5_row14_col18, #T_c5ab5_row17_col0, #T_c5ab5_row21_col0, #T_c5ab5_row23_col9, #T_c5ab5_row24_col10, #T_c5ab5_row25_col0, #T_c5ab5_row25_col7, #T_c5ab5_row25_col9, #T_c5ab5_row25_col18, #T_c5ab5_row27_col0, #T_c5ab5_row28_col0, #T_c5ab5_row29_col18, #T_c5ab5_row30_col4, #T_c5ab5_row31_col0, #T_c5ab5_row32_col9, #T_c5ab5_row33_col0, #T_c5ab5_row33_col13, #T_c5ab5_row33_col18 {
#   background-color: #9ccd9c;
#   color: #000000;
# }
# #T_c5ab5_row1_col1, #T_c5ab5_row1_col16, #T_c5ab5_row2_col18, #T_c5ab5_row3_col16, #T_c5ab5_row6_col6, #T_c5ab5_row6_col16, #T_c5ab5_row8_col18, #T_c5ab5_row9_col4, #T_c5ab5_row10_col18, #T_c5ab5_row12_col1, #T_c5ab5_row12_col16, #T_c5ab5_row12_col18, #T_c5ab5_row18_col10, #T_c5ab5_row18_col16, #T_c5ab5_row18_col18, #T_c5ab5_row19_col4, #T_c5ab5_row20_col16, #T_c5ab5_row21_col4, #T_c5ab5_row22_col16, #T_c5ab5_row24_col16, #T_c5ab5_row26_col16, #T_c5ab5_row30_col16, #T_c5ab5_row30_col18, #T_c5ab5_row32_col16, #T_c5ab5_row32_col18 {
#   background-color: #5eae5e;
#   color: #f1f1f1;
# }
# #T_c5ab5_row1_col3, #T_c5ab5_row2_col3 {
#   background-color: #d2e7d2;
#   color: #000000;
# }
# #T_c5ab5_row1_col4, #T_c5ab5_row4_col20, #T_c5ab5_row5_col18, #T_c5ab5_row6_col4, #T_c5ab5_row14_col10, #T_c5ab5_row15_col18, #T_c5ab5_row20_col20, #T_c5ab5_row22_col4, #T_c5ab5_row24_col15, #T_c5ab5_row25_col4, #T_c5ab5_row31_col10, #T_c5ab5_row33_col10 {
#   background-color: #6db66d;
#   color: #f1f1f1;
# }
# #T_c5ab5_row1_col5, #T_c5ab5_row18_col5, #T_c5ab5_row26_col7 {
#   background-color: #70b770;
#   color: #f1f1f1;
# }
# #T_c5ab5_row1_col6, #T_c5ab5_row14_col5, #T_c5ab5_row31_col15 {
#   background-color: #a8d2a8;
#   color: #000000;
# }
# #T_c5ab5_row1_col7, #T_c5ab5_row9_col5, #T_c5ab5_row11_col7, #T_c5ab5_row15_col7, #T_c5ab5_row19_col5, #T_c5ab5_row31_col5 {
#   background-color: #aed5ae;
#   color: #000000;
# }
# #T_c5ab5_row1_col8, #T_c5ab5_row22_col8, #T_c5ab5_row33_col9 {
#   background-color: #b7dab7;
#   color: #000000;
# }
# #T_c5ab5_row1_col12 {
#   background-color: #c9e2c8;
#   color: #000000;
# }
# #T_c5ab5_row1_col13, #T_c5ab5_row12_col13, #T_c5ab5_row28_col13 {
#   background-color: #309730;
#   color: #f1f1f1;
# }
# #T_c5ab5_row1_col14, #T_c5ab5_row5_col14, #T_c5ab5_row13_col14 {
#   background-color: #63b163;
#   color: #f1f1f1;
# }
# #T_c5ab5_row1_col15, #T_c5ab5_row6_col20, #T_c5ab5_row7_col20, #T_c5ab5_row8_col20, #T_c5ab5_row11_col15, #T_c5ab5_row11_col20, #T_c5ab5_row13_col15, #T_c5ab5_row13_col20, #T_c5ab5_row17_col1, #T_c5ab5_row29_col20, #T_c5ab5_row30_col1, #T_c5ab5_row33_col1 {
#   background-color: #49a449;
#   color: #f1f1f1;
# }
# #T_c5ab5_row1_col17, #T_c5ab5_row2_col17 {
#   background-color: #61b061;
#   color: #f1f1f1;
# }
# #T_c5ab5_row1_col19, #T_c5ab5_row21_col6, #T_c5ab5_row26_col6, #T_c5ab5_row33_col19 {
#   background-color: #65b265;
#   color: #f1f1f1;
# }
# #T_c5ab5_row1_col20, #T_c5ab5_row2_col13, #T_c5ab5_row3_col9, #T_c5ab5_row5_col5, #T_c5ab5_row5_col9, #T_c5ab5_row7_col4, #T_c5ab5_row7_col14, #T_c5ab5_row9_col0, #T_c5ab5_row10_col6, #T_c5ab5_row10_col7, #T_c5ab5_row10_col11, #T_c5ab5_row11_col18, #T_c5ab5_row12_col6, #T_c5ab5_row12_col10, #T_c5ab5_row17_col15, #T_c5ab5_row27_col3, #T_c5ab5_row28_col1, #T_c5ab5_row28_col2, #T_c5ab5_row28_col16, #T_c5ab5_row30_col3, #T_c5ab5_row31_col8, #T_c5ab5_row31_col11, #T_c5ab5_row31_col19, #T_c5ab5_row32_col2, #T_c5ab5_row33_col12, #T_c5ab5_row33_col17 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_c5ab5_row2_col0, #T_c5ab5_row2_col5, #T_c5ab5_row3_col0, #T_c5ab5_row5_col0, #T_c5ab5_row8_col3, #T_c5ab5_row11_col5, #T_c5ab5_row11_col12, #T_c5ab5_row19_col0, #T_c5ab5_row19_col13, #T_c5ab5_row20_col0, #T_c5ab5_row21_col3, #T_c5ab5_row22_col5, #T_c5ab5_row22_col12, #T_c5ab5_row24_col0, #T_c5ab5_row26_col15, #T_c5ab5_row29_col0, #T_c5ab5_row29_col15, #T_c5ab5_row29_col17, #T_c5ab5_row30_col0, #T_c5ab5_row32_col0

# %% [markdown]
# Examining line plots of the center of measure of each predictor over the year will allow for a more detailed analysis in how they've changed as the game of basketball has evolved. Some don't seem to change all that much like `TRB%` (*Total Rebounding Percentage*) while others have more drastic movement like the increase in `TS%` (*True Shooting Percentage*) or the increase in `OBPM` (*Offensive Box Plus/Minus*). Both `TS%` and `OBPM` have very drastic increases in the last decade or so.

# %%
# %matplotlib inline 

a = 1
b = 1

fig = plt.figure(figsize = (30,40))

for i in df_group.columns[:-1]:
    ax1 = fig.add_subplot(8,3,a)
    a += 1
    sns.lineplot(x='year', y=i, data=df_group)
    plt.xlabel('Season')
    plt.ylabel(str(i))
    plt.xticks(rotation = 45) 
    plt.title(str(i) + ' Trend')
    fig.tight_layout()
      
plt.show()

# %% [markdown]
# ## Median of Features by Position

# %% [markdown]
# If an analysis of the median of the features by season played is undergone then a comparison of this center of measure by position should also be shown. ALthough most recently some NBA pundits believe that the league has transitioned to being position-less, 5 somewhat distinct positions exist on a team which are center (C), power forward (PF), small forward (SF), shooting guard (SG), and point guard (PG). These positions may have some overlap in responsibilities but are in general accomplishing different functions on the court typically. For example, the front-court (forwards and center) may typically be expected to produce more rebounds while the back-court could play a larger role in distributing the ball and scoring. Examining the median for each position would confirm some of these notions.

# %%
pd.set_option('display.max_columns', None)
df_group_2 = df_all_NBA.groupby('Pos')[cols_all_list].median()
df_group_2
# Out:
#       Age   PER   TS%  3PAr   FTr   ORB%   DRB%   TRB%   AST%  STL%  BLK%  \
# Pos
# C    27.0  24.1  0.58  0.01  0.50  10.35  24.80  17.85  11.30   1.3  4.50
# PF   27.0  23.7  0.57  0.04  0.40   8.05  24.00  16.20  16.55   1.6  2.25
# PG   28.0  22.8  0.58  0.27  0.34   2.50  10.35   6.50  40.10   2.3  0.50
# SF   27.0  23.3  0.58  0.20  0.38   4.30  17.10  10.80  21.80   2.0  1.20
# SG   27.0  23.0  0.56  0.22  0.37   3.30  12.20   7.90  24.10   2.2  1.00
#
#       TOV%   USG%   OWS   DWS     WS  WS/48  OBPM  DBPM  BPM  VORP
# Pos
# C    12.65  26.65  6.10  4.70  10.90  0.200  2.80   1.8  4.8   4.3
# PF   11.70  28.20  6.95  4.35  11.15  0.200  4.05   1.1  5.4   5.1
# PG   14.10  25.80  8.00  3.00  10.60  0.195  5.35   0.4  5.4   5.0
# SF   12.30  29.40  7.50  3.50  10.80  0.190  5.20   1.2  5.5   5.2
# SG   11.30  30.90  7.80  3.20  10.70  0.190  5.10   0.4  5.4   4.9

# %%
a = 1

fig = plt.figure(figsize = (30,40))

for i in df_group_2.columns:
    ax1 = fig.add_subplot(7,3,a)
    a += 1
    sns.barplot(x=df_group_2.index, y=i, data=df_group_2, palette = "mako")
    plt.xlabel('Position')
    plt.ylabel(str(i))
    plt.xticks(rotation = 60) 
    plt.title(str(i) + ' Median for Each Position')
    fig.tight_layout()
     
plt.show()

# %% [markdown]
# There are some easy-takeaways that can be seen from the graphs above that'd indicate there is a difference for the median of our predictors across different positions. For example, `BLK%` (*Block Percentage*) has a much higher median for front-court All-NBA players than back-court All-NBA players. Same goes for any of the predictors that describe rebounding percentages. The opposite phenomenon occurs for a predictor like `STL%` (*Steal Percentage*). There are also some predictors that don't have a great difference in median across positions like `Age`, `PER`, or `TS%`.

# %% [markdown]
# ## Scatterplot of Variables vs. Share of Votes

# %% [markdown]
# Lastly, a scatterplot between the predictors and the share of All-NBA votes will be shown to demonstrate the relationship between the predictors and the response for each group of our `All_NBA_Boolean` response variable. These plots will expand on the previous portions of the EDA related to correlation but also visualize some of the non-All-NBA player's metrics compared to their All-NBA counterparts. Each plot can almost create two distinct spaces where each group of players exist.

# %%
 # %matplotlib inline 

a = 1

fig = plt.figure(figsize = (30,80))

for i in cols_all_list[:-1]:
    ax1 = fig.add_subplot(8,3,a)
    a += 1
    sns.scatterplot(x = 'All_NBA_Share', y = i, data = df,
               hue = 'All_NBA_Boolean',
               palette = "Set2")
    plt.xlabel('All-NBA Share of Votes')
    plt.ylabel(str(i))
    plt.title(str(i) + ' vs. All-NBA Share of Votes')
    fig.tight_layout()
     
plt.show()
